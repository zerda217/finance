# %%
import os 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import platform
import squarify # 트리맵

# %%
if platform.system() == 'Darwin': #맥
        plt.rc('font', family='AppleGothic') 
elif platform.system() == 'Windows': #윈도우
        plt.rc('font', family='Malgun Gothic') 

DATA_IN_PATH = './data/program/'
fileList = os.listdir(DATA_IN_PATH)
print(fileList)
# Out:
# ['고용, 고용노동일반, 노동 부문 주요 프로그램별 추이.CSV', '공적연금 부문 주요 프로그램별 추이.CSV', '기초생활보장 부문 주요 프로그램별 추이.CSV', '노인,아동·보육, 여성·가족·청소년 부문 주요 프로그램별.CSV', '보훈 부문 주요 프로그램별 추이.CSV', '사회복지일반 부문 주요 프로그램별 추이.CSV', '주택 부문 주요 프로그램별 추이.CSV', '취약계층지원 부문 주요 프로그램별 추이.CSV']

# %%
df = pd.read_csv(DATA_IN_PATH+'고용, 고용노동일반, 노동 부문 주요 프로그램별 추이.CSV', 
                 encoding='CP949')
df.drop(['기준', '연도'], inplace=True, axis=1)
x=df.columns.values.tolist() # 칼럼 명
lastRow = df.tail(1)
dfT=lastRow.transpose() # 행렬 바꾸기
dfT
plt.barh(np.arange(13), df.iloc[2])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
squarify.plot(sizes=dfT[6], label = dfT.index, value = dfT[6])
# Out:
# <AxesSubplot:>

# %%
plt.pie(dfT)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-46101c457b5a> in <module>
# ----> 1 plt.pie(dfT)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2825         textprops=None, center=(0, 0), frame=False,
#    2826         rotatelabels=False, *, normalize=None, data=None):
# -> 2827     return gca().pie(
#    2828         x, explode=explode, labels=labels, colors=colors,
#    2829         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...
